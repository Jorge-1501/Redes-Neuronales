# %% [markdown]
# # Ingreso a Drive y GitHub

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Física\ trabajos/6to\ semestre/
# Out:
# /content/drive/MyDrive/Física trabajos/6to semestre

# %%
# !ls
# Out:
#  config.py   Lab_optica  'Redes Neuronales'

# %%
from config import USER_EMAIL, USER_NAME, PASSWORD

PASS = PASSWORD
USUARIO = USER_NAME
EMAIL = USER_EMAIL


# !git config --global user.email {EMAIL}
# !git config --global user.name {USUARIO}
# !git config --global user.password {PASS}

# %%
# %cd ../../../
# Out:
# /content/drive

# %%
# %cd MyDrive/Física\ trabajos/6to\ semestre/Redes\ Neuronales/Redes-Neuronales/
# Out:
# [Errno 2] No such file or directory: 'MyDrive/Física trabajos/6to semestre/Redes Neuronales/'
# /content/drive/MyDrive/Física trabajos/6to semestre

# %%
# !git status
# Out:
# Refresh index: 100% (105/105), done.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Digitos/src/Tarea_5
# 	Series_de_tiempo.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git commit -m "Actualización para iniciar series de tiempo."
# !git push
# Out:
# [main f94d868] Commit externo, realizado fuera de los notebooks de Google Colab en lista.
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Digitos/src/Tarea4.ipynb
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 1.81 KiB | 462.00 KiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/Jorge-1501/Redes-Neuronales
#    f7b475e..f94d868  main -> main

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 3), reused 9 (delta 3), pack-reused 0
# Unpacking objects: 100% (9/9), 260.72 KiB | 227.00 KiB/s, done.
# From https://github.com/Jorge-1501/Redes-Neuronales
#    76ea93f..f7b475e  main       -> origin/main
# Updating 76ea93f..f7b475e
# Fast-forward
#  Digitos/src/__pycache__/Tarea_3.pdf | Bin 0 -> 470830 bytes
#  README.md                           |   3 +++
#  2 files changed, 3 insertions(+)
#  create mode 100644 Digitos/src/__pycache__/Tarea_3.pdf
